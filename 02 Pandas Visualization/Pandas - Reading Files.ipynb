# %% [markdown]
# # **Setup**

# %%
import pandas as pd
from IPython.display import YouTubeVideo

# %% [markdown]
# # **Info**

# %%
YouTubeVideo(id='dUpyC40cF6Q',width=500,height=300)

# %% [markdown]
# # **Data Import**
