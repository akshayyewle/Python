# %% [markdown]
# # **Setup**
#
# * https://www.youtube.com/watch?v=ooqXQ37XHMM

# %%
import pandas as pd 
import seaborn as sns

# %% [markdown]
# # **Get Inbuilt Datasets**

# %%
sns.get_dataset_names()
# Out:
# ['anagrams',
#  'anscombe',
#  'attention',
#  'brain_networks',
#  'car_crashes',
#  'diamonds',
#  'dots',
#  'dowjones',
#  'exercise',
#  'flights',
#  'fmri',
#  'geyser',
#  'glue',
#  'healthexp',
#  'iris',
#  'mpg',
#  'penguins',
#  'planets',
#  'seaice',
#  'taxis',
#  'tips',
#  'titanic']

# %%
tips = sns.load_dataset('tips')
iris = sns.load_dataset('iris')
titanic = sns.load_dataset('titanic')
planets = sns.load_dataset('planets')
penguins = sns.load_dataset('penguins')

# %%
tips
# Out:
#      total_bill   tip     sex smoker   day    time  size
# 0         16.99  1.01  Female     No   Sun  Dinner     2
# 1         10.34  1.66    Male     No   Sun  Dinner     3
# 2         21.01  3.50    Male     No   Sun  Dinner     3
# 3         23.68  3.31    Male     No   Sun  Dinner     2
# 4         24.59  3.61  Female     No   Sun  Dinner     4
# ..          ...   ...     ...    ...   ...     ...   ...
# 239       29.03  5.92    Male     No   Sat  Dinner     3
# 240       27.18  2.00  Female    Yes   Sat  Dinner     2
# 241       22.67  2.00    Male    Yes   Sat  Dinner     2
# 242       17.82  1.75    Male     No   Sat  Dinner     2
# 243       18.78  3.00  Female     No  Thur  Dinner     2
#
# [244 rows x 7 columns]

# %% [markdown]
# # **Plotting**

# %% [markdown]
# ## **Scatterplot**

# %%
# Basic Scatterplot
sns.scatterplot(tips,x='tip',y='total_bill')
# Out:
# <Axes: xlabel='tip', ylabel='total_bill'>

# %%
# Scatterplot With Hue
sns.scatterplot(tips,x='tip',y='total_bill',hue='day')
# Out:
# <Axes: xlabel='tip', ylabel='total_bill'>

# %%
# Scatterplot With Hue & Size | Custom Colour Pallet
sns.scatterplot(tips,x='tip',y='total_bill',hue='sex',size='size',palette='YlGnBu')
# Out:
# <Axes: xlabel='tip', ylabel='total_bill'>

# %% [markdown]
# ## **Histogram**

# %%
# Basic Histogram
sns.histplot(tips,x='tip')
# Out:
# <Axes: xlabel='tip', ylabel='Count'>

# %%
# Histogram With Bins
sns.histplot(tips,x='tip',bins=15)
# Out:
# <Axes: xlabel='tip', ylabel='Count'>

# %%
# Histogram With KDE
sns.histplot(tips,x='tip',bins=15,kde=True)
# Out:
# <Axes: xlabel='tip', ylabel='Count'>

# %%
# Specify Plotting Stat
sns.histplot(tips,x='tip',bins=15,stat = 'probability',kde=True)
# Out:
# <Axes: xlabel='tip', ylabel='Probability'>

# %% [markdown]
# ## **Displot**
#
# * Similar As Histplot() Function

# %%
# Specify Plotting Stat
sns.displot(tips,x='tip',bins=15,kde=True)

# %% [markdown]
# ## **Bar Plots**

# %%
sns.barplot(tips,x='sex',y='tip')
# Out:
# <Axes: xlabel='sex', ylabel='tip'>

# %% [markdown]
# ## **Box Plot**

# %%
# Basic Boxplot 
sns.boxplot(data=tips,x='sex',y='tip')
# Out:
# <Axes: xlabel='sex', ylabel='tip'>

# %%
# Basic Boxplot 
sns.boxplot(data=tips,x='day',y='tip',hue='sex',palette='YlGnBu')
# Out:
# <Axes: xlabel='day', ylabel='tip'>

# %% [markdown]
# ## **Strip Plot**
#
# * See distribution of data without the additional quartile details as shown in box plot

# %%
sns.stripplot(data=tips,x='day',y='tip',hue='sex',palette='YlGnBu')
# Out:
# <Axes: xlabel='day', ylabel='tip'>

# %%
# Enable Category Dodging
sns.stripplot(data=tips,x='day',y='tip',hue='sex',palette='YlGnBu',dodge=True)

# Separate Strip Plot For Each Hue Color
# Out:
# <Axes: xlabel='day', ylabel='tip'>

# %% [markdown]
# ## **Joint Plot**
# * https://seaborn.pydata.org/generated/seaborn.jointplot.html

# %%
sns.jointplot(data=tips,x='tip',y='total_bill')

# %%
# Show Regression Line
sns.jointplot(data=tips,x='tip',y='total_bill',kind='reg')

# %%
# Show KDE Lines
sns.jointplot(data=tips,x='tip',y='total_bill',kind='kde')

# %%
# Show KDE Lines With Shading
sns.jointplot(data=tips,x='tip',y='total_bill',kind='kde',fill=True)

# Note: fill argument was earlier called shade

# %%
# Show KDE Lines With Shading With Colour Scheme
sns.jointplot(data=tips,x='tip',y='total_bill',kind='kde',fill=True,cmap='RdYlGn')

# Note: Use cmap argument & not pallete

# %%
# Show Hex Line
sns.jointplot(data=tips,x='tip',y='total_bill',kind='hex')

# %% [markdown]
# ## **Pair Plot**
# * https://seaborn.pydata.org/generated/seaborn.pairplot.html

# %%
titanic.head()
# Out:
#    survived  pclass     sex   age  sibsp  parch     fare embarked  class  \
# 0         0       3    male  22.0      1      0   7.2500        S  Third
# 1         1       1  female  38.0      1      0  71.2833        C  First
# 2         1       3  female  26.0      0      0   7.9250        S  Third
# 3         1       1  female  35.0      1      0  53.1000        S  First
# 4         0       3    male  35.0      0      0   8.0500        S  Third
#
#      who  adult_male deck  embark_town alive  alone
# 0    man        True  NaN  Southampton    no  False
# 1  woman       False    C    Cherbourg   yes  False
# 2  woman       False  NaN  Southampton   yes   True
# 3  woman       False    C  Southampton   yes  False
# 4    man        True  NaN  Southampton    no   True

# %%
sns.pairplot(data=titanic.select_dtypes(include='number'),hue='pclass')

# %% [markdown]
# ## **Heatmap**

# %%
titanic.corr(numeric_only=True)
# Out:
#             survived    pclass       age     sibsp     parch      fare  \
# survived    1.000000 -0.338481 -0.077221 -0.035322  0.081629  0.257307
# pclass     -0.338481  1.000000 -0.369226  0.083081  0.018443 -0.549500
# age        -0.077221 -0.369226  1.000000 -0.308247 -0.189119  0.096067
# sibsp      -0.035322  0.083081 -0.308247  1.000000  0.414838  0.159651
# parch       0.081629  0.018443 -0.189119  0.414838  1.000000  0.216225
# fare        0.257307 -0.549500  0.096067  0.159651  0.216225  1.000000
# adult_male -0.557080  0.094035  0.280328 -0.253586 -0.349943 -0.182024
# alone      -0.203367  0.135207  0.198270 -0.584471 -0.583398 -0.271832
#
#             adult_male     alone
# survived     -0.557080 -0.203367
# pclass        0.094035  0.135207
# age           0.280328  0.198270
# sibsp        -0.253586 -0.584471
# parch        -0.349943 -0.583398
# fare         -0.182024 -0.271832
# adult_male    1.000000  0.404744
# alone         0.404744  1.000000

# %%
sns.heatmap(titanic.corr(numeric_only=True),annot=True)
# Out:
# <Axes: >

# %%
sns.heatmap(titanic.corr(numeric_only=True),annot=True,vmin=-1,vmax=1,center=0)
# Out:
# <Axes: >

# %%
# Coolwarm Colour Theme
sns.heatmap(titanic.corr(numeric_only=True),annot=True,vmin=-1,vmax=1,center=0,cmap='coolwarm')
# Out:
# <Axes: >

# %%
# Ice Fire Colour Theme
sns.heatmap(titanic.corr(numeric_only=True),annot=True,vmin=-1,vmax=1,center=0,cmap='icefire')
# Out:
# <Axes: >

# %% [markdown]
# ## **Cluster Map**
#
# * https://seaborn.pydata.org/generated/seaborn.clustermap.html

# %%
sns.clustermap(data=iris.select_dtypes('number'))

# %% [markdown]
# ## **Penguin Dataset Example**

# %%
penguins.head()
# Out:
#   species     island  bill_length_mm  bill_depth_mm  flipper_length_mm  \
# 0  Adelie  Torgersen            39.1           18.7              181.0
# 1  Adelie  Torgersen            39.5           17.4              186.0
# 2  Adelie  Torgersen            40.3           18.0              195.0
# 3  Adelie  Torgersen             NaN            NaN                NaN
# 4  Adelie  Torgersen            36.7           19.3              193.0
#
#    body_mass_g     sex
# 0       3750.0    Male
# 1       3800.0  Female
# 2       3250.0  Female
# 3          NaN     NaN
# 4       3450.0  Female

# %%
sns.clustermap(data=penguins.select_dtypes('number').dropna())

# Note: Scale Of Values in "body_mass_g" column is different from values in other columns
# Hence, we need to standardize the values across all the columns

# %%
sns.clustermap(data=penguins.select_dtypes('number').dropna(),standard_scale=True,metric='euclidean',figsize=(5,5))

# %%
# Use Manhatten Distance As Clustering Metric
sns.clustermap(data=penguins.select_dtypes('number').dropna(),standard_scale=True,metric='cityblock',figsize=(5,5))

# %%
# Use Correlation Distance As Clustering Metric
sns.clustermap(data=penguins.select_dtypes('number').dropna(),standard_scale=True,metric='correlation',figsize=(5,5))

# %% [markdown]
# ## **Use Row Colour Option**

# %%
penguins.head()
# Out:
#   species     island  bill_length_mm  bill_depth_mm  flipper_length_mm  \
# 0  Adelie  Torgersen            39.1           18.7              181.0
# 1  Adelie  Torgersen            39.5           17.4              186.0
# 2  Adelie  Torgersen            40.3           18.0              195.0
# 3  Adelie  Torgersen             NaN            NaN                NaN
# 4  Adelie  Torgersen            36.7           19.3              193.0
#
#    body_mass_g     sex
# 0       3750.0    Male
# 1       3800.0  Female
# 2       3250.0  Female
# 3          NaN     NaN
# 4       3450.0  Female

# %%
# Unique Values In Species Column
penguins['species'].unique()
# Out:
# array(['Adelie', 'Chinstrap', 'Gentoo'], dtype=object)

# %%
# Use Row Colour Option
species_color = penguins.species.map({'Adelie':'blue','Chinstrap':'red','Gentoo':'green'})

print(type(species_color))
print(len(species_color))
# Out:
# <class 'pandas.core.series.Series'>
# 344

# %%
sns.clustermap(data=penguins.select_dtypes('number').dropna(),standard_scale=True,
               figsize=(7,7),
               row_colors=species_color)

# %% [markdown]
# # **Seaborn Colour Palettes**
#
# * https://www.youtube.com/watch?v=2wRHBodrWuY
# * https://medium.com/@morganjonesartist/color-guide-to-seaborn-palettes-da849406d44f

# %% [markdown]
# ## **Get Current Colour Palette**

# %%
sns.color_palette()
# Out:
# [(0.12156862745098039, 0.4666666666666667, 0.7058823529411765),
#  (1.0, 0.4980392156862745, 0.054901960784313725),
#  (0.17254901960784313, 0.6274509803921569, 0.17254901960784313),
#  (0.8392156862745098, 0.15294117647058825, 0.1568627450980392),
#  (0.5803921568627451, 0.403921568627451, 0.7411764705882353),
#  (0.5490196078431373, 0.33725490196078434, 0.29411764705882354),
#  (0.8901960784313725, 0.4666666666666667, 0.7607843137254902),
#  (0.4980392156862745, 0.4980392156862745, 0.4980392156862745),
#  (0.7372549019607844, 0.7411764705882353, 0.13333333333333333),
#  (0.09019607843137255, 0.7450980392156863, 0.8117647058823529)]

# %% [markdown]
# ## **Check Other Colour Palette**

# %%
sns.color_palette('bone')
# Out:
# [(0.12352941176470589, 0.12352936342706163, 0.17186700767263427),
#  (0.25049019607843137, 0.25049009806043054, 0.3485080988917306),
#  (0.3740196078431372, 0.3944852761182057, 0.49901949512261384),
#  (0.5009803921568627, 0.5690563247931928, 0.6259803080024994),
#  (0.6245098039215686, 0.7389092370175045, 0.7495097475613068),
#  (0.8069852246322835, 0.8764705882352941, 0.8764705604411924)]

# %%
sns.color_palette('terrain')
# Out:
# [(0.011764705882352955, 0.5764705882352941, 0.9764705882352941),
#  (0.1450980392156863, 0.8290196078431373, 0.42901960784313725),
#  (0.7098039215686275, 0.9419607843137255, 0.5419607843137255),
#  (0.8549019607843137, 0.8142745098039216, 0.5216470588235294),
#  (0.5725490196078431, 0.45286274509803925, 0.36917647058823533),
#  (0.7176470588235294, 0.6385882352941177, 0.6216470588235294)]

# %%
sns.color_palette('icefire')
# Out:
# [(0.33355526, 0.64107876, 0.80445484),
#  (0.28708711, 0.32912157, 0.69034504),
#  (0.15652427, 0.15348248, 0.22238175),
#  (0.22994394, 0.13076731, 0.15146314),
#  (0.61319563, 0.1824336, 0.2687872),
#  (0.91463791, 0.43668557, 0.21367954)]

# %%
sns.color_palette('Accent')
# Out:
# [(0.4980392156862745, 0.788235294117647, 0.4980392156862745),
#  (0.7450980392156863, 0.6823529411764706, 0.8313725490196079),
#  (0.9921568627450981, 0.7529411764705882, 0.5254901960784314),
#  (1.0, 1.0, 0.6),
#  (0.2196078431372549, 0.4235294117647059, 0.6901960784313725),
#  (0.9411764705882353, 0.00784313725490196, 0.4980392156862745),
#  (0.7490196078431373, 0.3568627450980392, 0.09019607843137253),
#  (0.4, 0.4, 0.4)]

# %%
sns.color_palette('Blues')
# Out:
# [(0.8584083044982699, 0.9134486735870818, 0.9645674740484429),
#  (0.7309496347558632, 0.8394771241830065, 0.9213225682429834),
#  (0.5356862745098039, 0.746082276047674, 0.8642522106881968),
#  (0.32628988850442137, 0.6186236063052672, 0.802798923490965),
#  (0.16696655132641292, 0.48069204152249134, 0.7291503267973857),
#  (0.044059976931949255, 0.3338869665513264, 0.6244521337946944)]

# %%
sns.color_palette('BrBG')
# Out:
# [(0.6313725490196078, 0.3951557093425605, 0.09573241061130335),
#  (0.8572856593617839, 0.7257977700884274, 0.4471357170319107),
#  (0.9636293733179546, 0.9237985390234525, 0.8185313341022683),
#  (0.8299115724721262, 0.9294886582083814, 0.9152633602460593),
#  (0.4615916955017304, 0.7748558246828146, 0.7299500192233758),
#  (0.0878892733564014, 0.479123414071511, 0.44775086505190315)]

# %% [markdown]
# ## **Reversed Palette**

# %%
sns.color_palette('BrBG')
# Out:
# [(0.6313725490196078, 0.3951557093425605, 0.09573241061130335),
#  (0.8572856593617839, 0.7257977700884274, 0.4471357170319107),
#  (0.9636293733179546, 0.9237985390234525, 0.8185313341022683),
#  (0.8299115724721262, 0.9294886582083814, 0.9152633602460593),
#  (0.4615916955017304, 0.7748558246828146, 0.7299500192233758),
#  (0.0878892733564014, 0.479123414071511, 0.44775086505190315)]

# %%
# Reversed Palette
sns.color_palette('BrBG_r')
# Out:
# [(0.08788927335640145, 0.47912341407151104, 0.4477508650519032),
#  (0.4615916955017303, 0.7748558246828144, 0.7299500192233757),
#  (0.8299115724721262, 0.9294886582083814, 0.9152633602460593),
#  (0.9636293733179546, 0.9237985390234525, 0.8185313341022683),
#  (0.8572856593617839, 0.7257977700884275, 0.4471357170319108),
#  (0.6313725490196078, 0.3951557093425605, 0.09573241061130335)]

# %% [markdown]
# ## **Extract Colours From Color Palette**

# %%
# Length Of Color Palette
len(sns.color_palette('BrBG'))
# Out:
# 6

# %%
for i in range(len(sns.color_palette('BrBG'))):
    print(sns.color_palette('BrBG_r')[i])

sns.color_palette('BrBG_r')
# Out:
# (0.08788927335640145, 0.47912341407151104, 0.4477508650519032)
# (0.4615916955017303, 0.7748558246828144, 0.7299500192233757)
# (0.8299115724721262, 0.9294886582083814, 0.9152633602460593)
# (0.9636293733179546, 0.9237985390234525, 0.8185313341022683)
# (0.8572856593617839, 0.7257977700884275, 0.4471357170319108)
# (0.6313725490196078, 0.3951557093425605, 0.09573241061130335)
# [(0.08788927335640145, 0.47912341407151104, 0.4477508650519032),
#  (0.4615916955017303, 0.7748558246828144, 0.7299500192233757),
#  (0.8299115724721262, 0.9294886582083814, 0.9152633602460593),
#  (0.9636293733179546, 0.9237985390234525, 0.8185313341022683),
#  (0.8572856593617839, 0.7257977700884275, 0.4471357170319108),
#  (0.6313725490196078, 0.3951557093425605, 0.09573241061130335)]

# %% [markdown]
# ## **Use A Specific Colour From Palette For Plotting**

# %%
# Default Seaborn Plot Color
sns.scatterplot(tips,x='tip',y='total_bill')
# Out:
# <Axes: xlabel='tip', ylabel='total_bill'>

# %%
# Extract A Color
Color_01 = sns.color_palette('BrBG_r')[0]

# Plot With The Extracted Color
sns.scatterplot(tips,x='tip',y='total_bill',color=Color_01)
sns.color_palette('BrBG_r')
# Out:
# [(0.08788927335640145, 0.47912341407151104, 0.4477508650519032),
#  (0.4615916955017303, 0.7748558246828144, 0.7299500192233757),
#  (0.8299115724721262, 0.9294886582083814, 0.9152633602460593),
#  (0.9636293733179546, 0.9237985390234525, 0.8185313341022683),
#  (0.8572856593617839, 0.7257977700884275, 0.4471357170319108),
#  (0.6313725490196078, 0.3951557093425605, 0.09573241061130335)]

# %% [markdown]
# ## **Create A Custom Palette**

# %% [markdown]
# ### **Single Color Palette**

# %%
# Light Palette - Starts With Lighter Shade Of Specified Color
sns.light_palette('blue')
# Out:
# [(0.9427942677547513, 0.942825384792593, 0.9519953287278279),
#  (0.754235414203801, 0.7542603078340744, 0.9615962629822623),
#  (0.5656765606528508, 0.5656952308755558, 0.9711971972366967),
#  (0.3771177071019005, 0.3771301539170372, 0.9807981314911312),
#  (0.18855885355095026, 0.18856507695851854, 0.9903990657455656),
#  (0.0, 0.0, 1.0)]

# %%
# Dark Palette - Starts With Dark Shade Of Specified Color
sns.dark_palette('blue')
# Out:
# [(0.14289171628325356, 0.14289583210240445, 0.19919851992384108),
#  (0.11431337302660285, 0.11431666568192356, 0.3593588159390729),
#  (0.08573502976995213, 0.08573749926144267, 0.5195191119543047),
#  (0.05715668651330143, 0.05715833284096178, 0.6796794079695364),
#  (0.028578343256650707, 0.02857916642048089, 0.8398397039847683),
#  (0.0, 0.0, 1.0)]

# %%
# Crimson Color Palette
sns.light_palette('crimson')
# Out:
# [(0.9518458706913332, 0.9411685470430606, 0.9416261497237904),
#  (0.9340257161609097, 0.7686211121442524, 0.8003597433084441),
#  (0.9162055616304862, 0.5960736772454442, 0.6590933368930978),
#  (0.8983854071000628, 0.42352624234663605, 0.5178269304777514),
#  (0.8805652525696392, 0.25097880744782775, 0.37656052406240503),
#  (0.8627450980392157, 0.0784313725490196, 0.23529411764705882)]

# %%
# Crimson Color Palette
sns.dark_palette('crimson')
# Out:
# [(0.18827002942527166, 0.1342869812629642, 0.13772985866612683),
#  (0.3231650431480605, 0.12311585952017529, 0.15724271046231322),
#  (0.4580600568708493, 0.11194473777738637, 0.17675556225849964),
#  (0.5929550705936381, 0.10077361603459745, 0.19626841405468604),
#  (0.7278500843164268, 0.08960249429180853, 0.21578126585087243),
#  (0.8627450980392157, 0.0784313725490196, 0.23529411764705882)]

# %% [markdown]
# ### **Multi-Color Palette**

# %%
sns.blend_palette(['blue','red'])
# Out:
# [(0.0, 0.0, 1.0),
#  (0.2, 0.0, 0.8),
#  (0.4, 0.0, 0.6),
#  (0.6, 0.0, 0.4),
#  (0.8, 0.0, 0.19999999999999996),
#  (1.0, 0.0, 0.0)]

# %%
sns.blend_palette(['red','orange','green'])
# Out:
# [(1.0, 0.0, 0.0),
#  (1.0, 0.25882352941176473, 0.0),
#  (1.0, 0.5176470588235295, 0.0),
#  (0.8, 0.6180392156862745, 0.0),
#  (0.4, 0.56, 0.0),
#  (0.0, 0.5019607843137255, 0.0)]

# %%
# Expand The Color Palette To Have Specified Number Of Shades
sns.blend_palette(['red','orange','green'],10)

# Note That by default blend_palette() function creates 6 shades.
# Out:
# [(1.0, 0.0, 0.0),
#  (1.0, 0.14209919261822376, 0.0),
#  (1.0, 0.2841983852364475, 0.0),
#  (1.0, 0.43137254901960786, 0.0),
#  (1.0, 0.5734717416378317, 0.0),
#  (0.8862745098039215, 0.6305574778931181, 0.0),
#  (0.6666666666666667, 0.5986928104575163, 0.0),
#  (0.4392156862745098, 0.5656901191849288, 0.0),
#  (0.2196078431372549, 0.5338254517493272, 0.0),
#  (0.0, 0.5019607843137255, 0.0)]

# %% [markdown]
# ### **Custom Palette To Highlight Specific Categories**

# %%
tips.head()
# Out:
#    total_bill   tip     sex smoker  day    time  size
# 0       16.99  1.01  Female     No  Sun  Dinner     2
# 1       10.34  1.66    Male     No  Sun  Dinner     3
# 2       21.01  3.50    Male     No  Sun  Dinner     3
# 3       23.68  3.31    Male     No  Sun  Dinner     2
# 4       24.59  3.61  Female     No  Sun  Dinner     4

# %%
tips['day'].unique()
# Out:
# ['Sun', 'Sat', 'Thur', 'Fri']
# Categories (4, object): ['Thur', 'Fri', 'Sat', 'Sun']

# %%
Color_Palette_01 = {x: 'gray' for x in tips['day'].unique()}
print(Color_Palette_01)

# Add Highlighting Color
Color_Palette_01['Sat'] = 'crimson'
print(Color_Palette_01)
# Out:
# {'Sun': 'gray', 'Sat': 'gray', 'Thur': 'gray', 'Fri': 'gray'}
# {'Sun': 'gray', 'Sat': 'crimson', 'Thur': 'gray', 'Fri': 'gray'}

# %%
# Scatterplot With Custom Palette
sns.scatterplot(tips,x='tip',y='total_bill',hue='day',palette=Color_Palette_01)
# Out:
# <Axes: xlabel='tip', ylabel='total_bill'>

# %%
# Displot With Default Palette
sns.displot(tips,x='tip',hue='day',col='day')

# %%
# Displot With Custom Higlighting Palette
sns.displot(tips,x='tip',hue='day',col='day',palette=Color_Palette_01)

# %% [markdown]
# ### **Cube-Helix Palettes**

# %%
# Default Cube-Helix Palette
sns.cubehelix_palette()
# Out:
# [[0.9312692223325372, 0.8201921796082118, 0.7971480974663592],
#  [0.8559578605899612, 0.6418993116910497, 0.6754191211563135],
#  [0.739734329496642, 0.4765280683170713, 0.5959617419736206],
#  [0.57916573903086, 0.33934576125314425, 0.5219003947563425],
#  [0.37894937987024996, 0.2224702044652721, 0.41140014301575434],
#  [0.1750865648952205, 0.11840023306916837, 0.24215989137836502]]

# %%
# Custom Cube-Helix Palette
sns.cubehelix_palette(start=1,rot=1,light=0.75,dark=0.4,n_colors=10)
# Out:
# [[0.8119066206230451, 0.699512742745189, 0.8786983192489379],
#  [0.7445633058527953, 0.6692873261190314, 0.8679737025305014],
#  [0.669187083999078, 0.6449528239346878, 0.8475601572978924],
#  [0.5894295707954631, 0.6251849493967849, 0.8146017431816268],
#  [0.5094733721889907, 0.6081170208220943, 0.7677035872449477],
#  [0.4335475618564019, 0.5915611213567767, 0.7070670847275126],
#  [0.36544702214027847, 0.5732601451330271, 0.634448898575594],
#  [0.30810543811750724, 0.5511441232205231, 0.5529506765229713],
#  [0.2632658761794211, 0.5235640916826487, 0.4666630846787446],
#  [0.2312828968499689, 0.48947916994159585, 0.38020207491334873]]

# %%
# Shorthand Notation 
sns.color_palette('ch:1,r=1,l=0.75,d=0.4',10)
# Out:
# [(0.8119066206230451, 0.699512742745189, 0.8786983192489379),
#  (0.7445633058527953, 0.6692873261190314, 0.8679737025305014),
#  (0.669187083999078, 0.6449528239346878, 0.8475601572978924),
#  (0.5894295707954631, 0.6251849493967849, 0.8146017431816268),
#  (0.5094733721889907, 0.6081170208220943, 0.7677035872449477),
#  (0.4335475618564019, 0.5915611213567767, 0.7070670847275126),
#  (0.36544702214027847, 0.5732601451330271, 0.634448898575594),
#  (0.30810543811750724, 0.5511441232205231, 0.5529506765229713),
#  (0.2632658761794211, 0.5235640916826487, 0.4666630846787446),
#  (0.2312828968499689, 0.48947916994159585, 0.38020207491334873)]

# %% [markdown]
# ### **HUSL Palettes**
#
# * aka HSL Palette
# * H: Hue
# * S: Saturation
# * L: Lightness

# %%
# Default HSL Palette
sns.husl_palette()
# Out:
# [(0.9677975592919913, 0.44127456009157356, 0.5358103155058701),
#  (0.7350228985632719, 0.5952719904750953, 0.1944419133847522),
#  (0.3126890019504329, 0.6928754610296064, 0.1923704830330379),
#  (0.21044753832183283, 0.6773105080456748, 0.6433941168468681),
#  (0.23299120924703914, 0.639586552066035, 0.9260706093977744),
#  (0.9082572436765556, 0.40195790729656516, 0.9576909250290225)]

# %%
# Custom HSL Palette
sns.husl_palette(h=0.6,s=0.5,l=0.8)
# Out:
# [(0.5761656714354562, 0.8049448197700536, 0.8721109029054733),
#  (0.7839230151299358, 0.7513337644177233, 0.8864315879843234),
#  (0.8905342184799655, 0.723319242361496, 0.8086977576143501),
#  (0.8978043750716032, 0.7358077390900221, 0.6582231123097002),
#  (0.7452397199964109, 0.7941530215686314, 0.5427144719984334),
#  (0.5570782883810265, 0.8238760300721931, 0.7145224219712418)]

# %% [markdown]
# ### **XKCD Palettes**
#
# * Most Commonly Identifed Colours By Their Generic Names
# * https://xkcd.com/color/rgb/
# * Survey Results: https://blog.xkcd.com/2010/05/03/color-survey-results/

# %%
# Specify Each Color Individually
sns.xkcd_palette(['neon pink','slate','goldenrod'])
# Out:
# [(0.996078431372549, 0.00392156862745098, 0.6039215686274509),
#  (0.3176470588235294, 0.396078431372549, 0.4470588235294118),
#  (0.9803921568627451, 0.7607843137254902, 0.0196078431372549)]

# %% [markdown]
# ### **Crayon Palette**
#
# * https://en.wikipedia.org/wiki/List_of_Crayola_crayon_colors

# %%
sns.crayon_palette(['Macaroni and Cheese','Timberwolf','Jazzberry Jam'])
# Out:
# [(1.0, 0.7411764705882353, 0.5333333333333333),
#  (0.8588235294117647, 0.8431372549019608, 0.8235294117647058),
#  (0.792156862745098, 0.21568627450980393, 0.403921568627451)]

# %% [markdown]
# ### **Custom Palette Using Color Codes**

# %%
sns.color_palette(['red','#33AAFF','#FFDD33'])
# Out:
# [(1.0, 0.0, 0.0),
#  (0.2, 0.6666666666666666, 1.0),
#  (1.0, 0.8666666666666667, 0.2)]

# %% [markdown]
# # **Color Selection Widget**

# %%
sns.choose_colorbrewer_palette(data_type='qualitative',as_cmap=True)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# c:\Users\aksha\OneDrive\06 Data Science & Analytics\Github\Python\05 Searbon Tutorial\Python Code 00.ipynb Cell 106 line 1
# ----> <a href='vscode-notebook-cell:/c%3A/Users/aksha/OneDrive/06%20Data%20Science%20%26%20Analytics/Github/Python/05%20Searbon%20Tutorial/Python%20Code%2000.ipynb#Y221sZmlsZQ%3D%3D?line=0'>1</a> sns.choose_colorbrewer_palette(data_type='qualitative',as_cmap=True)
#
# File c:\Users\aksha\AppData\Local\Programs\Python\Python311\Lib\site-packages\seaborn\widgets.py:80, in choose_colorbrewer_palette(data_type, as_cmap)
#      48 """Select a palette from the ColorBrewer set.
#      49
#      50 These palettes are built into matplotlib and can be used by name in
#    (...)
#      77
#      78 """
#      79 if data_type.startswith("q") and as_cmap:
# ...
